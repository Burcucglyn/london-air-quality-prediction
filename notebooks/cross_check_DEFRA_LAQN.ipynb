# %% [markdown]
# # Cross Check MetaData Pollutants Site Location List at Each Dataset

# %% [markdown]
# What I'm gonna do here:
# - laqn metadata path : /Users/burdzhuchaglayan/Desktop/data science projects/air-pollution-levels/data/laqn/updated_actv_siteSpecies.csv
# - defra metadata path:  /Users/burdzhuchaglayan/Desktop/data science projects/air-pollution-levels/data/defra/test/std_london_sites_pollutant.csv
#
# 1) I will be check both file structures:
#      - LAQN:
#         - SiteCode,SiteName,SiteType,SpeciesCode,SpeciesName,Latitude,Longitude
#         - BG1,Barking and Dagenham - Rush Green,Suburban,NO2,Nitrogen Dioxide,51.563752,0.177891
#
#     - DEFRA:
#         - station_id,station_name,pollutant_available,pollutant_air,latitude,longitude,timeseries_id,pollutant,pollutant_std
#         - 785876,Borehamwood Meadow Park,Nitrogen dioxide,air,51.661229,-0.2705499999910774,4565.0,6875 - Borehamwood Meadow Park-Nitrogen dioxide (air),NO2
# 2) Common column list for both file:
#     - LAQN:
#         - SpeciesCode,Latitude,Longitude
#
#     - DEFRA:
#         - pollutant,latitude,longitude
#
# 3) pairing for both file:
#
# SpeciesCode = pollutant
# Latitude = latitude
# Longitude = longitude
#
# 4) DEFRA got 37 pollutants, LAQN only 6, so having the pollutants as a primary key won't work. Checking through the coordinates would give the matching result.
